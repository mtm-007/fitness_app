# %%
import pandas as pd

# %%
df = pd.read_csv('../data/data_uncleaned.csv', sep=';')

# %%
df_cleaned = df.drop_duplicates(subset='Exercise Name')

# %%
df_cleaned
# Out:
#                                       Exercise Name Type of Activity  \
# 0                                           Push-Up         Strength
# 1                                      Goblet Squat         Strength
# 2                                          Deadlift         Strength
# 3                                             Plank         Mobility
# 4                                  Kettlebell Swing           Cardio
# ..                                              ...              ...
# 286                             Overhead Plate Hold         Strength
# 287  Shoulder CARs (Controlled Articular Rotations)         Mobility
# 288                      Isometric Split Squat Hold         Strength
# 289                               Band Pull-Through         Strength
# 290                 Supine Hamstring Stretch (Band)         Mobility
#
#     Type of Equipment   Body Part     Type  \
# 0          Bodyweight  Upper Body     Push
# 1            Dumbbell  Lower Body     Push
# ...

# %%
df_cleaned.columns = df_cleaned.columns.str.lower().str.replace(' ', '_')

# %%
df_cleaned.to_csv('../data/data.csv',index=False)
